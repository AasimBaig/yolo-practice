# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %%
data = pd.read_csv("vott-csv-export/test2-export.csv")

# %%
data.head()
# Out:
#                                  image        xmin        ymin        xmax  \
# 0  vlcsnap-2019-10-20-14h13m08s668.png  346.312997  151.804245  475.331565
# 1  vlcsnap-2019-10-20-14h13m08s668.png  861.255526  195.955189  997.064545
# 2  vlcsnap-2019-10-20-14h12m54s012.png  737.895668   74.823113  928.028294
# 3  vlcsnap-2019-10-20-14h12m54s012.png  371.211317   68.030660  595.296198
# 4  vlcsnap-2019-10-20-14h12m58s782.png  482.122016  150.672170  711.865606
#
#          ymax   label
# 0  301.238208  Rachel
# 1  348.785377    Ross
# 2  262.747642  Monica
# 3  283.125000    Ross
# 4  356.709906  Rachel

# %%
numClasses = ["Ross","Rachel","Joey","Monica","Pheobe","Chandler"]

# %%
u = data.loc[data['label'].isin(numClasses)]

# %%
keep_col = ["image","xmin","ymin","xmax","ymax","label"]
new_f = u[keep_col]

# %%
new_f['ClassNumber'] = new_f['label']

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
new_f["ClassNumber"] = lb.fit_transform(new_f["ClassNumber"])

# %%
#dw = 1./1280
#dh = 1./720
#print(dw)
#print(dh)
# Out:
# 0.00078125
# 0.001388888888888889

# %%
new_f['width'] = (new_f['xmax'] - new_f['xmin'])
#new_f['width'] = new_f['width'] * dw
new_f['height'] = (new_f['ymax'] - new_f['ymin'])
#new_f['height'] = new_f['height'] * dh
new_f['x'] = new_f['xmin']
#new_f['x'] = (new_f['xmax'] + new_f['xmin'])/2
#new_f['x'] = new_f['x'] * dw
new_f['y'] = new_f['ymin']/2
#new_f['y'] = (new_f['ymax'] + new_f['ymin'])/2
#new_f['y'] = new_f['y'] * dh
keep_col = ['ClassNumber','image','x','y','width','height']
new_f_2 = new_f[keep_col]

# %%
new_f_2.head()
# Out:
#    ClassNumber                                image           x          y  \
# 0            4  vlcsnap-2019-10-20-14h13m08s668.png  346.312997  75.902123
# 1            5  vlcsnap-2019-10-20-14h13m08s668.png  861.255526  97.977594
# 2            2  vlcsnap-2019-10-20-14h12m54s012.png  737.895668  37.411557
# 3            5  vlcsnap-2019-10-20-14h12m54s012.png  371.211317  34.015330
# 4            4  vlcsnap-2019-10-20-14h12m58s782.png  482.122016  75.336085
#
#         width      height
# 0  129.018568  149.433962
# 1  135.809019  152.830189
# 2  190.132626  187.924528
# 3  224.084881  215.094340
# 4  229.743590  206.037736

# %%
'''
def from_yolo_to_cor(box, shape):
    img_h, img_w, _ = shape
    # x1, y1 = ((x + witdth)/2)*img_width, ((y + height)/2)*img_height
    # x2, y2 = ((x - witdth)/2)*img_width, ((y - height)/2)*img_height
    x1, y1 = int((box[0] + box[2]/2)*img_w), int((box[1] + box[3]/2)*img_h)
    x2, y2 = int((box[0] - box[2]/2)*img_w), int((box[1] - box[3]/2)*img_h)
    return x1, y1, x2, y2
    
def draw_boxes(img, boxes):
    for box in boxes:
        x1, y1, x2, y2 = from_yolo_to_cor(box, shape)
        cv2.rectangle(img, (x1, y1), (x2, y2), (0,255,0), 3)
    plt.imshow(img)


'''
# Out:
# '\ndef from_yolo_to_cor(box, shape):\n    img_h, img_w, _ = shape\n    # x1, y1 = ((x + witdth)/2)*img_width, ((y + height)/2)*img_height\n    # x2, y2 = ((x - witdth)/2)*img_width, ((y - height)/2)*img_height\n    x1, y1 = int((box[0] + box[2]/2)*img_w), int((box[1] + box[3]/2)*img_h)\n    x2, y2 = int((box[0] - box[2]/2)*img_w), int((box[1] - box[3]/2)*img_h)\n    return x1, y1, x2, y2\n    \ndef draw_boxes(img, boxes):\n    for box in boxes:\n        x1, y1, x2, y2 = from_yolo_to_cor(box, shape)\n        cv2.rectangle(img, (x1, y1), (x2, y2), (0,255,0), 3)\n    plt.imshow(img)\n\n\n'

# %%
import os
for root, dirs, files in os.walk("vott-csv-export/"):  
	for filename in files:

		if filename.endswith(".jpg"):
			fn = filename[:-4]
			nf = new_f_2.loc[new_f_2['image'] == fn]
			keep_col = ['ClassNumber','x','y','width','height']
			new_nf = nf[keep_col]
			print(new_nf)
			imgpath = "D:\Kaggle_Comp\yolo-od\vott-csv-export" + fn + ".txt"
			print(imgpath)
			new_nf.to_csv(imgpath, index=False, header=False, sep=' ')

# %%
keep_col = ['ClassNumber','x','y','width','height']
new_2 = new_f_2[keep_col]
new_2.to_csv("new_csv2.txt",index=False,header=False,sep=" ")

# %%
from matplotlib.patches import Rectangle
from matplotlib import patches

# %%
fig,ax = plt.subplots(1)
p = plt.imread("vott-csv-export/vlcsnap-2019-10-20-14h13m08s668.png")
ax.imshow(p)
rect1 = patches.Rectangle(xy=(861.25,195.95),width=130,height=151,linewidth=1,edgecolor='b',facecolor='none')
rect2 = patches.Rectangle(xy=(346,151),width=135,height=152,linewidth=1,edgecolor='r',facecolor='none')
ax.add_patch(rect1)
ax.add_patch(rect2)
plt.tight_layout()

# %%
img = cv2.imread("vott-csv-export/vlcsnap-2019-10-20-14h13m08s668.png")
spoint = (346,151)
lpoint = (475,301)
color = (255,0,0)
img2 = cv2.rectangle(img,lpoint,spoint,(255,0,0),5)
cv2.imshow("image",img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("vott-csv-export/vlcsnap-2019-10-20-14h12m54s012.png",cv2.IMREAD_COLOR)

# %%
x1 = ((0.320955+0.100796)/2)*1280
y1 = ((0.314613+0.207547)/2)*720
x2 = ((0.320955-0.100796)/2)*1280
y2 = ((0.314613-0.207547)/2)*720
print(x1,y1,x2,y2)
# Out:
# 269.92064 187.9776 140.90176 38.543759999999985

# %%
dw = 1./1280
dh = 1./720
print(dw)
print(dh)
# Out:
# 0.00078125
# 0.001388888888888889

# %%
xmin = 346
ymin = 151
xmax = 475
ymax = 301

width =  (xmax - xmin)
height = (ymax-ymin)

d_width = width * dw
d_height = height * dh

print("width",width)
print("height",height)

print("d_width",d_width)
print("d_height",d_height)

xx = xmin
yy = ymin

d_xx = xx * dw
d_yy = yy * dh

print("xx",xx)
print("yy",yy)

print("d_xx",d_xx)
print("d_yy",d_yy)
# Out:
# width 129
# height 150
# d_width 0.10078125
# d_height 0.20833333333333334
# xx 346
# yy 151
# d_xx 0.2703125
# d_yy 0.20972222222222223

# %%
# xmin, ymin = ((x + witdth)/2)*img_width, ((y + height)/2)*img_height
    # xmax, ymax = ((x - witdth)/2)*img_width, ((y - height)/2)*img_height
    
    
xmin2 = ((d_xx + d_width)/2)*1280
print(xmin2)
# Out:
# 237.5
